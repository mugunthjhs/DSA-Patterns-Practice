# %%
input = 5 

end_char = ord("A")

for i in range(input,0,-1):
    for j in range(i):
        print(chr(end_char+j),end=" ")
    print()
# Out:
# A B C D E
# A B C D
# A B C
# A B
# A

# %%
input = ["ab", "cd", "ef", "gh", "ij", "kl"]

offset = 4

print(input[offset-1])
# Out:
# gh

# %%
a = 2, 4, 6, 8
b = 3, 6, 9

print(a[0],b[0])
# Out:
# 2 3

# %%
2+3
# Out:
# 5

# %%
end_char = ord("A")

for i in range(5,0,-1):
    for j in range(i):
        print(chr(end_char + j),end=" ")
    print()
# Out:
# A B C D E
# A B C D
# A B C
# A B
# A
